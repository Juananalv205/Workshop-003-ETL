# %% [markdown]
# ## First Stept
# - 📚 Import essential libraries for data manipulation, visualization, and system access.
# - 🛠️ Set up paths for accessing custom modules.
# - 🖥️ Configure display options for DataFrames to improve readability.
# - 📊 Load datasets for the years 2015 to 2019, preparing them for analysis.

# %%
# Import Libraries
import sys                   # Provides access to system-specific parameters and functions.
import os                    # Allows interaction with the operating system, such as file handling and path manipulation.
import pandas as pd          # Imports Pandas, a library for data manipulation and analysis.
import matplotlib.pyplot as plt  # Imports Matplotlib's plotting module for creating static, animated, and interactive visualizations.
import seaborn as sns        # Imports Seaborn, a statistical data visualization library built on Matplotlib for enhanced visual appeal and additional plot types.
import numpy as np
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.impute import SimpleImputer

# %%
# Add the 'src' folder to sys.path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

#import previously created classes
from utils.data_analysis_functions import DataAnalyzer

# %%
# Set display options for DataFrame columns
pd.set_option('display.max_columns', None)  # Set to None to display all columns without limitation
pd.set_option('display.max_colwidth', None)  # Do not limit the width of column content
pd.set_option('display.expand_frame_repr', False)  # Prevent pandas from breaking the DataFrame into multiple lines

# %%
# Import data
data_2015 = pd.read_csv('../data/raw/2015.csv')  # Loads the 2015 dataset from a CSV file located in the specified directory and assigns it to `data_2015`.
data_2016 = pd.read_csv('../data/raw/2016.csv')  # Loads the 2016 dataset from a CSV file in the specified directory and assigns it to `data_2016`.
data_2017 = pd.read_csv('../data/raw/2017.csv')  # Loads the 2017 dataset from a CSV file in the specified directory and assigns it to `data_2017`.
data_2018 = pd.read_csv('../data/raw/2018.csv')  # Loads the 2018 dataset from a CSV file in the specified directory and assigns it to `data_2018`.
data_2019 = pd.read_csv('../data/raw/2019.csv')  # Loads the 2019 dataset from a CSV file in the specified directory and assigns it to `data_2019`.

# %% [markdown]
# ## Second Step:
# - 📄 Display the first few rows of the dataset, retrieve its shape, and list the names of the columns to understand its structure and available features.
# - 🔍 Get an overview of data types and missing values for each column to summarize the dataset's information.
# - 📊 Select numeric columns for analysis while excluding non-numeric columns and generate descriptive statistics for these selected columns.
# - 📈 Create histograms to visualize the distribution of numeric data across the dataset.

# %% [markdown]
# - Year 2015

# %%
# Displays the first five rows of the 2015 dataset to provide a quick overview of the data structure and contents.
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  Generosity  Dystopia Residual
# 0  Switzerland  Western Europe               1            7.587         0.03411                   1.39651  1.34951                   0.94143  0.66557                        0.41978     0.29678            2.51738
# 1      Iceland  Western Europe               2            7.561         0.04884                   1.30232  1.40223                   0.94784  0.62877                        0.14145     0.43630            2.70201
# 2      Denmark  Western Europe               3            7.527         0.03328                   1.32548  1.36058                   0.87464  0.64938                        0.48357     0.34139            2.49204
# ...

# %%
# Returns a tuple representing the dimensions of the 2015 dataset, showing the number of rows and columns.
data_2015.shape
# Out:
# (158, 12)

# %%
# Returns the column names of the 2015 dataset, providing insight into the features available for analysis.
data_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Displays a summary of the 2015 dataset, including data types, non-null counts, and memory usage, to help understand the dataset's structure and completeness.
data_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# Initializes a DataAnalyzer object with the 2015 dataset for statistical analysis.
analyzer_statistic = DataAnalyzer(data_2015)

# Selects all columns except the first two for numeric analysis.
data_2015_numeric_columns = data_2015.columns[2:]

# Analyzes the selected numeric columns and combines the results into a new DataFrame.
statistics_numeric_data_2015 = analyzer_statistic.analyze_and_combine(data_2015_numeric_columns)

# Displays the resulting statistics for the numeric data from the 2015 dataset.
statistics_numeric_data_2015
# Out:
#                      Column Name Data Type  Unique Values  Repeated Values  Missing Values  count       mean        std      min        25%        50%         75%        max   Mode  Variance  Skewness  Kurtosis
# 0              Dystopia Residual   float64            158                0               0  158.0   2.098977   0.553550  0.32858   1.759410   2.095415    2.462415    3.60214   0.33      0.31     -0.24      0.53
# 1       Economy (GDP per Capita)   float64            158                0               0  158.0   0.846137   0.403121  0.00000   0.545808   0.910245    1.158448    1.69042   0.00      0.16     -0.32     -0.87
# 2                         Family   float64            158                0               0  158.0   0.991046   0.272369  0.00000   0.856823   1.029510    1.214405    1.40223   0.00      0.07     -1.01      0.92
# ...

# %%
# Selects only the numeric columns from the DataFrame using the previously identified column names.
numerical_data_2015 = data_2015[data_2015_numeric_columns]

# Configures the style of the plots using Seaborn for better aesthetics.
sns.set(rc={"axes.facecolor": "#F2EAC5", "figure.facecolor": "#F2EAC5"})

# Creates histograms for each numeric column in the DataFrame to visualize their distributions.
numerical_data_2015.hist(figsize=(20, 15), bins=30, xlabelsize=8, ylabelsize=8)

# Adjusts the layout of the plots to prevent overlapping and improve readability.
plt.tight_layout()

# Displays the generated histograms.
plt.show()

# %% [markdown]
# - Year 2016

# %%
# Displays the first five rows of the 2016 dataset to provide a quick overview of its structure and contents.
data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Lower Confidence Interval  Upper Confidence Interval  Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  Generosity  Dystopia Residual
# 0      Denmark  Western Europe               1            7.526                      7.460                      7.592                   1.44178  1.16374                   0.79504  0.57941                        0.44453     0.36171            2.73939
# 1  Switzerland  Western Europe               2            7.509                      7.428                      7.590                   1.52733  1.14524                   0.86303  0.58557                        0.41203     0.28083            2.69463
# ...

# %%
# Returns a tuple representing the dimensions of the 2016 dataset, showing the number of rows and columns.
data_2016.shape
# Out:
# (157, 13)

# %%
# Returns the column names of the 2016 dataset, providing insight into the features available for analysis.
data_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
# Displays a summary of the 2016 dataset, including data types, non-null counts, and memory usage, to help understand the dataset's structure and completeness.
data_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
# Initializes a DataAnalyzer object with the 2016 dataset for statistical analysis.
analyzer_statistic = DataAnalyzer(data_2016)

# Selects all columns except the first three for numeric analysis.
data_2016_numeric_columns = data_2016.columns[3:]

# Analyzes the selected numeric columns and combines the results into a new DataFrame.
statistics_numeric_data_2016 = analyzer_statistic.analyze_and_combine(data_2016_numeric_columns)

# Displays the resulting statistics for the numeric data from the 2016 dataset.
statistics_numeric_data_2016
# Out:
#                      Column Name Data Type  Unique Values  Repeated Values  Missing Values  count      mean       std      min      25%      50%      75%      max  Mode  Variance  Skewness  Kurtosis
# 0              Dystopia Residual   float64            157                0               0  157.0  2.325807  0.542220  0.81789  2.03171  2.29074  2.66465  3.83772  0.82      0.29     -0.17      0.59
# 1       Economy (GDP per Capita)   float64            157                0               0  157.0  0.953880  0.412595  0.00000  0.67024  1.02780  1.27964  1.82427  0.00      0.17     -0.38     -0.71
# 2                         Family   float64            157                0               0  157.0  0.793621  0.266706  0.00000  0.64184  0.84142  1.02152  1.18326  0.00      0.07     -0.86      0.20
# ...

# %%
# Selects only the numeric columns from the DataFrame using the previously identified column names.
numerical_data_2016 = data_2016[data_2016_numeric_columns]

# Configures the style of the plots using Seaborn for better aesthetics.
sns.set(rc={"axes.facecolor": "#F2EAC5", "figure.facecolor": "#F2EAC5"})

# Creates histograms for each numeric column in the DataFrame to visualize their distributions.
numerical_data_2016.hist(figsize=(20, 15), bins=30, xlabelsize=8, ylabelsize=8)

# Adjusts the layout of the plots to prevent overlapping and improve readability.
plt.tight_layout()

# Displays the generated histograms.
plt.show()

# %% [markdown]
# - Year 2017

# %%
# Displays the first five rows of the 2017 dataset to provide a quick overview of its structure and contents.
data_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0       Norway               1            7.537      7.594445     7.479556                  1.616463  1.533524                  0.796667  0.635423    0.362012                       0.315964           2.277027
# 1      Denmark               2            7.522      7.581728     7.462272                  1.482383  1.551122                  0.792566  0.626007    0.355280                       0.400770           2.313707
# 2      Iceland               3            7.504      7.622030     7.385970                  1.480633  1.610574                  0.833552  0.627163    0.475540                       0.153527           2.322715
# ...

# %%
# Returns a tuple representing the dimensions of the 2017 dataset, showing the number of rows and columns.
data_2017.shape
# Out:
# (155, 12)

# %%
# Returns the column names of the 2017 dataset, providing insight into the features available for analysis.
data_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
# Displays a summary of the 2017 dataset, including data types, non-null counts, and memory usage, to help understand the dataset's structure and completeness.
data_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
# Initializes a DataAnalyzer object with the 2017 dataset for statistical analysis.
analyzer_statistic = DataAnalyzer(data_2017)

# Selects all columns except the first two for numeric analysis.
data_2017_numeric_columns = data_2017.columns[2:]

# Analyzes the selected numeric columns and combines the results into a new DataFrame.
statistics_numeric_data_2017 = analyzer_statistic.analyze_and_combine(data_2017_numeric_columns)

# Displays the resulting statistics for the numeric data from the 2017 dataset.
statistics_numeric_data_2017
# Out:
#                      Column Name Data Type  Unique Values  Repeated Values  Missing Values  count      mean       std       min       25%       50%       75%       max  Mode  Variance  Skewness  Kurtosis
# 0              Dystopia.Residual   float64            155                0               0  155.0  1.850238  0.500028  0.377914  1.591291  1.832910  2.144654  3.117485  0.38      0.25     -0.24      0.69
# 1       Economy..GDP.per.Capita.   float64            155                0               0  155.0  0.984718  0.420793  0.000000  0.663371  1.064578  1.318027  1.870766  0.00      0.18     -0.39     -0.68
# 2                         Family   float64            155                0               0  155.0  1.188898  0.287263  0.000000  1.042635  1.253918  1.414316  1.610574  0.00      0.08     -1.18      1.54
# ...

# %%
# Selects only the numeric columns from the DataFrame using the previously identified column names.
numerical_data_2017 = data_2017[data_2017_numeric_columns]

# Configures the style of the plots using Seaborn for better aesthetics.
sns.set(rc={"axes.facecolor": "#F2EAC5", "figure.facecolor": "#F2EAC5"})

# Creates histograms for each numeric column in the DataFrame to visualize their distributions.
numerical_data_2017.hist(figsize=(20, 15), bins=30, xlabelsize=8, ylabelsize=8)

# Adjusts the layout of the plots to prevent overlapping and improve readability.
plt.tight_layout()

# Displays the generated histograms.
plt.show()

# %% [markdown]
# - Year 2018

# %%
# Displays the first five rows of the 2018 dataset to provide a quick overview of its structure and contents.
data_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  Healthy life expectancy  Freedom to make life choices  Generosity  Perceptions of corruption
# 0             1           Finland  7.632           1.305           1.592                    0.874                         0.681       0.202                      0.393
# 1             2            Norway  7.594           1.456           1.582                    0.861                         0.686       0.286                      0.340
# 2             3           Denmark  7.555           1.351           1.590                    0.868                         0.683       0.284                      0.408
# 3             4           Iceland  7.495           1.343           1.644                    0.914                         0.677       0.353                      0.138
# ...

# %%
# Returns a tuple representing the dimensions of the 2018 dataset, showing the number of rows and columns.
data_2018.shape
# Out:
# (156, 9)

# %%
# Returns the column names of the 2018 dataset, providing insight into the features available for analysis.
data_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# Displays a summary of the 2018 dataset, including data types, non-null counts, and memory usage, to help understand the dataset's structure and completeness.
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# Initializes a DataAnalyzer object with the 2018 dataset for performing statistical analysis.
analyzer_statistic = DataAnalyzer(data_2018)

# Selects all columns except the first two for numeric analysis.
data_2018_numeric_columns = data_2018.columns[2:]

# Analyzes the selected numeric columns and combines the results into a new DataFrame.
statistics_numeric_data_2018 = analyzer_statistic.analyze_and_combine(data_2018_numeric_columns)

# Displays the resulting statistics for the numeric data from the 2018 dataset.
statistics_numeric_data_2018
# Out:
#                     Column Name Data Type  Unique Values  Repeated Values  Missing Values  count      mean       std    min      25%     50%      75%    max  Mode  Variance  Skewness  Kurtosis
# 0  Freedom to make life choices   float64            136               20               0  156.0  0.454506  0.162424  0.000  0.35600  0.4870  0.57850  0.724  0.31      0.03     -0.79      0.11
# 1                GDP per capita   float64            147                9               0  156.0  0.891449  0.391921  0.000  0.61625  0.9495  1.19775  2.096  0.33      0.15     -0.21     -0.34
# 2                    Generosity   float64            122               34               0  156.0  0.181006  0.098471  0.000  0.10950  0.1740  0.23900  0.598  0.09      0.01      0.87      1.44
# 3       Healthy life expectancy   float64            143               13               0  156.0  0.597346  0.247579  0.000  0.42225  0.6440  0.77725  1.030  0.34      0.06     -0.53     -0.57
# ...

# %%
# Selects only the numeric columns from the 2018 DataFrame using the previously defined column names.
numerical_data_2018 = data_2018[data_2018_numeric_columns]

# Configures the style of the plots using Seaborn, setting the background colors for better aesthetics.
sns.set(rc={"axes.facecolor": "#F2EAC5", "figure.facecolor": "#F2EAC5"})

# Creates histograms for each numeric column in the 2018 dataset, providing a visual representation of the data distribution.
numerical_data_2018.hist(figsize=(20, 15), bins=30, xlabelsize=8, ylabelsize=8)

# Adjusts the layout of the plots to prevent overlapping and ensure clarity in visualizations.
plt.tight_layout()

# Displays the generated histograms.
plt.show()

# %% [markdown]
# - Year 2019

# %%
# Displays the first few rows of the 2019 dataset to provide a quick preview of its contents and structure.
data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  Healthy life expectancy  Freedom to make life choices  Generosity  Perceptions of corruption
# 0             1           Finland  7.769           1.340           1.587                    0.986                         0.596       0.153                      0.393
# 1             2           Denmark  7.600           1.383           1.573                    0.996                         0.592       0.252                      0.410
# 2             3            Norway  7.554           1.488           1.582                    1.028                         0.603       0.271                      0.341
# 3             4           Iceland  7.494           1.380           1.624                    1.026                         0.591       0.354                      0.118
# ...

# %%
# Retrieves the shape of the 2019 dataset, providing information on the number of rows and columns.
data_2019.shape
# Out:
# (156, 9)

# %%
# Lists the names of the columns in the 2019 dataset to understand its structure and available features.
data_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# Provides a summary of the 2019 dataset, including data types, non-null counts, and memory usage.
data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# Initializes the DataAnalyzer with the 2019 dataset and selects numeric columns for analysis, excluding the first two columns.
analyzer_statistic = DataAnalyzer(data_2019)

# Selects numeric columns from the dataset by excluding the first two columns.
data_2019_numeric_columns = data_2019.columns[2:]

# Analyzes the selected numeric columns and generates descriptive statistics for them.
statistics_numeric_data_2019 = analyzer_statistic.analyze_and_combine(data_2019_numeric_columns)

# Displays the statistics for the numeric data in the 2019 dataset.
statistics_numeric_data_2019
# Out:
#                     Column Name Data Type  Unique Values  Repeated Values  Missing Values  count      mean       std    min      25%     50%      75%    max  Mode  Variance  Skewness  Kurtosis
# 0  Freedom to make life choices   float64            130               26               0  156.0  0.392571  0.143289  0.000  0.30800  0.4170  0.50725  0.631  0.50      0.02     -0.69     -0.07
# 1                GDP per capita   float64            146               10               0  156.0  0.905147  0.398389  0.000  0.60275  0.9600  1.23250  1.684  0.96      0.16     -0.39     -0.77
# 2                    Generosity   float64            118               38               0  156.0  0.184846  0.095254  0.000  0.10875  0.1775  0.24825  0.566  0.15      0.01      0.75      1.17
# 3       Healthy life expectancy   float64            119               37               0  156.0  0.725244  0.242124  0.000  0.54775  0.7890  0.88175  1.141  0.82      0.06     -0.61     -0.30
# ...

# %%
# Selects only the numeric columns from the 2019 DataFrame using the previously defined column names.
numerical_data_2019 = data_2019[data_2019_numeric_columns]

# Sets the style for the plots using Seaborn to define the background colors for axes and the figure.
sns.set(rc={"axes.facecolor": "#F2EAC5", "figure.facecolor": "#F2EAC5"})

# Creates histograms for each numeric column in the DataFrame to visualize their distributions.
numerical_data_2019.hist(figsize=(20, 15), bins=30, xlabelsize=8, ylabelsize=8)

# Adjusts the layout to prevent overlap between subplots and ensures a clean display of the histograms.
plt.tight_layout()

# Displays the histograms generated in the previous step.
plt.show()

# %% [markdown]
# ## Third Step

# %%
# Function to find duplicate countries within a DataFrame
def find_duplicate_countries(data, year, country_column):
    # Count the occurrences of each country
    country_counts = data[country_column].value_counts()  
    # Filter the countries that appear more than once
    duplicate_countries = country_counts[country_counts > 1]
    # Print the results
    if not duplicate_countries.empty:
        print(f"Duplicates in {year}:")
        print(duplicate_countries)
    else:
        print(f"There are no duplicate countries in {year}.")

# Check for duplicates for each year
find_duplicate_countries(data_2015, "2015", "Country")
find_duplicate_countries(data_2016, "2016", "Country")
find_duplicate_countries(data_2017, "2017", "Country")
find_duplicate_countries(data_2018, "2018", "Country or region")    
find_duplicate_countries(data_2019, "2019", "Country or region")
# Out:
# There are no duplicate countries in 2015.
# There are no duplicate countries in 2016.
# There are no duplicate countries in 2017.
# There are no duplicate countries in 2018.
# There are no duplicate countries in 2019.

# %%
# Extract unique countries from each dataset
countries_2015 = set(data_2015['Country'])
countries_2016 = set(data_2016['Country'])
countries_2017 = set(data_2017['Country'])
countries_2018 = set(data_2018['Country or region'])
countries_2019 = set(data_2019['Country or region'])

# Compare the sets of countries
all_countries = countries_2015 & countries_2016 & countries_2017 & countries_2018 & countries_2019  # Intersection of all sets
country_counts = {
    "2015": len(countries_2015),
    "2016": len(countries_2016),
    "2017": len(countries_2017),
    "2018": len(countries_2018),
    "2019": len(countries_2019),
    "Common Countries": len(all_countries)
}

# Display the results
print(country_counts)

# Check if all datasets have the same number of countries
if all(len(countries) == len(countries_2015) for countries in [countries_2016, countries_2017, countries_2018, countries_2019]):
    print("All datasets have the same number of countries.")
else:
    print("The datasets have different numbers of countries.")
# Out:
# {'2015': 158, '2016': 157, '2017': 155, '2018': 156, '2019': 156, 'Common Countries': 141}
# The datasets have different numbers of countries.

# %%
# Create sets of (country, region) pairs for 2015 and 2016
countries_regions_2015 = dict(zip(data_2015['Country'], data_2015['Region']))  # Change 'Region' to the correct column name if necessary
countries_regions_2016 = dict(zip(data_2016['Country'], data_2016['Region']))  # Change 'Region' to the correct column name if necessary

# Create a list to store the differences
differences_list = []

# Iterate over the countries from 2015
for country in countries_regions_2015:
    if country in countries_regions_2016:  # Only consider countries that are in both years
        region_2015 = countries_regions_2015[country]
        region_2016 = countries_regions_2016[country]
        
        if region_2015 != region_2016:  # Only add if there is a difference in the region
            differences_list.append({
                'Country': country,
                'Region Year 2015': region_2015,
                'Region Year 2016': region_2016
            })

# Create a DataFrame from the list of differences
differences_df = pd.DataFrame(differences_list)

# Count the differences
num_differences = len(differences_df)

# Print results
if num_differences == 0:
    print("There are no differences in regions for common countries in 2015 and 2016.")
else:
    print(f"There are {num_differences} different (Country, Region) pairs between 2015 and 2016 for common countries.")
    differences_df  # Display the DataFrame with the differences
# Out:
# There are no differences in regions for common countries in 2015 and 2016.

# %% [markdown]
# ## Mini limpieza

# %%
columns_df_2015 = list(data_2015.columns)
columns_df_2016 = list(data_2016.columns)
columns_df_2017 = list(data_2017.columns)
columns_df_2018 = list(data_2018.columns)
columns_df_2019 = list(data_2019.columns)

# Get the maximum length of columns across all years
max_length = max(len(columns) for columns in [columns_df_2015, columns_df_2016, columns_df_2017, columns_df_2018, columns_df_2019])

# Ensure each list has the same length by padding with None values
for columns in [columns_df_2015, columns_df_2016, columns_df_2017, columns_df_2018, columns_df_2019]:
    while len(columns) < max_length:
        columns.append(None)

# Create a dictionary with column names for each year
data = {
    'columns_2015': columns_df_2015,
    'columns_2016': columns_df_2016,
    'columns_2017': columns_df_2017,
    'columns_2018': columns_df_2018,
    'columns_2019': columns_df_2019
}

# Create a DataFrame to display the column names for each year
columns_df = pd.DataFrame(data)
columns_df
# Out:
#                      columns_2015                   columns_2016                   columns_2017                  columns_2018                  columns_2019
# 0                         Country                        Country                        Country                  Overall rank                  Overall rank
# 1                          Region                         Region                 Happiness.Rank             Country or region             Country or region
# 2                  Happiness Rank                 Happiness Rank                Happiness.Score                         Score                         Score
# 3                 Happiness Score                Happiness Score                   Whisker.high                GDP per capita                GDP per capita
# 4                  Standard Error      Lower Confidence Interval                    Whisker.low                Social support                Social support
# ...

# %%
#drop columns that are not in all datasets
data_2015.drop(columns=['Standard Error'], inplace=True)

# %%
# Diccionario de renombramiento
rename_dict = {
    'Country': 'country',
    'Country or region': 'country',
    'Happiness Rank': 'happiness_rank',
    'Happiness.Rank': 'happiness_rank',
    'Overall rank': 'happiness_rank',
    'Happiness Score': 'happiness_score',
    'Happiness.Score': 'happiness_score',
    'Score': 'happiness_score',
    'Freedom': 'freedom',
    'Freedom to make life choices': 'freedom',
    'Economy (GDP per Capita)': 'economy_GDP_per_capita',
    'Economy..GDP.per.Capita.': 'economy_GDP_per_capita',
    'GDP per capita': 'economy_GDP_per_capita',
    'Social support': 'family',
    'Family': 'family',
    'Health (Life Expectancy)': 'health_life_expectancy',
    'Health..Life.Expectancy.': 'health_life_expectancy',
    'Healthy life expectancy': 'health_life_expectancy',
    'Trust (Government Corruption)': 'government_corruption',
    'Trust..Government.Corruption.': 'government_corruption',
    'Perceptions of corruption': 'government_corruption',
    'Generosity': 'generosity',
    'Region': 'region'
}

# Crear un conjunto de las columnas estándar (valores únicos del diccionario) e incluir 'region' en todos los años
standard_columns = set(rename_dict.values()).union({'region'})

# Renombrar las columnas y asegurar que 'year' esté al final en cada DataFrame
for df, year in zip([data_2015, data_2016, data_2017, data_2018, data_2019], [2015, 2016, 2017, 2018, 2019]):
    # Renombrar columnas
    df.rename(columns=rename_dict, inplace=True)
    
    # Añadir la columna 'region' con valores NaN si no existe en el DataFrame actual
    if 'region' not in df.columns:
        df['region'] = np.nan
    
    # Filtrar para conservar solo las columnas estándar, incluida 'region'
    df = df.loc[:, [col for col in df.columns if col in standard_columns]]
    
    # Añadir la columna 'year'
    df['year'] = year
    
    # Reordenar las columnas para que 'year' esté al final
    cols = [col for col in df.columns if col not in ['year']] + ['year']
    df = df.loc[:, cols]  # Esto reordenará las columnas y pondrá 'year' al final

    # Actualizar el DataFrame original
    if year == 2015:
        data_2015 = df
    elif year == 2016:
        data_2016 = df
    elif year == 2017:
        data_2017 = df
    elif year == 2018:
        data_2018 = df
    elif year == 2019:
        data_2019 = df

# %%
# Get the column names for each year and sort them alphabetically
        
        
columns_df_2015 = sorted(data_2015.columns)
columns_df_2016 = sorted(data_2016.columns)
columns_df_2017 = sorted(data_2017.columns)
columns_df_2018 = sorted(data_2018.columns)
columns_df_2019 = sorted(data_2019.columns)

# Determine the maximum length of columns across all years
max_length = max(len(columns) for columns in [columns_df_2015, columns_df_2016, columns_df_2017, columns_df_2018, columns_df_2019])

# Ensure each list has the same length by padding with None values
for columns in [columns_df_2015, columns_df_2016, columns_df_2017, columns_df_2018, columns_df_2019]:
    while len(columns) < max_length:
        columns.append(None)

# Create a dictionary with the sorted column names for each year
data = {
    'columns_2015': columns_df_2015,
    'columns_2016': columns_df_2016,
    'columns_2017': columns_df_2017,
    'columns_2018': columns_df_2018,
    'columns_2019': columns_df_2019
}

# Create a DataFrame to display the sorted column names for each year
columns_df = pd.DataFrame(data)
columns_df
# Out:
#               columns_2015            columns_2016            columns_2017            columns_2018            columns_2019
# 0                  country                 country                 country                 country                 country
# 1   economy_GDP_per_capita  economy_GDP_per_capita  economy_GDP_per_capita  economy_GDP_per_capita  economy_GDP_per_capita
# 2                   family                  family                  family                  family                  family
# 3                  freedom                 freedom                 freedom                 freedom                 freedom
# 4               generosity              generosity              generosity              generosity              generosity
# 5    government_corruption   government_corruption   government_corruption   government_corruption   government_corruption
# 6           happiness_rank          happiness_rank          happiness_rank          happiness_rank          happiness_rank
# ...

# %%
#concatenamos los datasets
#especificamos el orden de las columnas

concat_column_order = ['happiness_rank','country','region','happiness_score','economy_GDP_per_capita','family','health_life_expectancy','freedom','government_corruption','generosity','year']
df_concat = pd.concat([data_2015[concat_column_order], data_2016[concat_column_order], data_2017[concat_column_order], data_2018[concat_column_order], data_2019[concat_column_order]], ignore_index=True)

# %%
df_concat.head()
# Out:
#    happiness_rank      country          region  happiness_score  economy_GDP_per_capita   family  health_life_expectancy  freedom  government_corruption  generosity  year
# 0               1  Switzerland  Western Europe            7.587                 1.39651  1.34951                 0.94143  0.66557                0.41978     0.29678  2015
# 1               2      Iceland  Western Europe            7.561                 1.30232  1.40223                 0.94784  0.62877                0.14145     0.43630  2015
# 2               3      Denmark  Western Europe            7.527                 1.32548  1.36058                 0.87464  0.64938                0.48357     0.34139  2015
# 3               4       Norway  Western Europe            7.522                 1.45900  1.33095                 0.88521  0.66973                0.36503     0.34699  2015
# ...

# %%
print(f'In this moment have {df_concat['region'].isnull().sum()} countrys without region')
# Out:
# In this moment have 467 countrys without region

# %%
# Paso 1: Filtrar los años 2015 y 2016 para crear el diccionario de mapeo de regiones
# Filtrar para obtener solo las filas de 2015 y 2016, y seleccionar las columnas relevantes
region_mapping_df = df_concat[df_concat['year'].isin([2015, 2016])][['country', 'region']]

# Eliminar duplicados para asegurarnos de que cada país tiene una región única
region_mapping_df.drop_duplicates(subset=['country', 'region'], inplace=True)

# Crear el diccionario de mapeo donde la clave es el país y el valor es la región
region_mapping = region_mapping_df.set_index('country')['region'].to_dict()

# Paso 2: Rellenar las regiones faltantes en df_concat utilizando el diccionario
# Usamos map para asignar las regiones de acuerdo con el diccionario, sin sobreescribir las existentes
df_concat['region'] = df_concat['region'].fillna(df_concat['country'].map(region_mapping))

# Ahora `df_concat` tiene las regiones faltantes rellenadas usando los datos de 2015 y 2016.

# %%
print(f'In this moment have {df_concat['region'].isnull().sum()} countrys without region')
# Out:
# In this moment have 8 countrys without region

# %%
# Filtrar los países donde la columna 'region' sigue siendo NaN
paises_sin_region = df_concat[df_concat['region'].isna()]['country'].unique()

# Mostrar la lista de países sin región
print("Countries without an assigned region after the clean-up process:")
print(paises_sin_region)
# Out:
# Countries without an assigned region after the clean-up process:
# ['Taiwan Province of China' 'Hong Kong S.A.R., China' 'Trinidad & Tobago'
#  'Northern Cyprus' 'North Macedonia' 'Gambia']

# %%
# Diccionario para asignar manualmente las regiones de los países faltantes
regiones_manual = {
    'Taiwan Province of China': 'Eastern Asia',
    'Hong Kong S.A.R., China': 'Eastern Asia',
    'Trinidad & Tobago': 'Latin America and Caribbean',
    'Northern Cyprus': 'Middle East and Northern Africa',
    'North Macedonia': 'Central and Eastern Europe',
    'Gambia': 'Sub-Saharan Africa'
}

# Asignar las regiones a los países faltantes
df_concat['region'] = df_concat.apply(
    lambda row: regiones_manual.get(row['country'], row['region']),
    axis=1
)

# Verificar si hay países que todavía no tienen región asignada
paises_sin_region_actualizado = df_concat[df_concat['region'].isna()]['country'].unique()
print("Countries with no region assigned after manual update:")
print(paises_sin_region_actualizado)
# Out:
# Countries with no region assigned after manual update:
# []

# %% [markdown]
# ## Fourth step: EDA data concat

# %%
df_concat.head()
# Out:
#    happiness_rank      country          region  happiness_score  economy_GDP_per_capita   family  health_life_expectancy  freedom  government_corruption  generosity  year
# 0               1  Switzerland  Western Europe            7.587                 1.39651  1.34951                 0.94143  0.66557                0.41978     0.29678  2015
# 1               2      Iceland  Western Europe            7.561                 1.30232  1.40223                 0.94784  0.62877                0.14145     0.43630  2015
# 2               3      Denmark  Western Europe            7.527                 1.32548  1.36058                 0.87464  0.64938                0.48357     0.34139  2015
# 3               4       Norway  Western Europe            7.522                 1.45900  1.33095                 0.88521  0.66973                0.36503     0.34699  2015
# ...

# %%
print(f"The dataset have {df_concat.shape[0]} rows and {df_concat.shape[1]} columns.")
# Out:
# The dataset have 782 rows and 11 columns.

# %%
df_concat.columns
# Out:
# Index(['happiness_rank', 'country', 'region', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'government_corruption', 'generosity', 'year'],
#       dtype='object')

# %%
# Initializes the DataAnalyzer with the 2019 dataset and selects numeric columns for analysis, excluding the first two columns.
analyzer_statistic = DataAnalyzer(df_concat)

# Selects numeric columns from the dataset by excluding the first two columns.
df_numericas = df_concat.columns[4:]
# Analyzes the selected numeric columns and generates descriptive statistics for them.
statistics_numeric_data= analyzer_statistic.analyze_and_combine(df_numericas)

# Displays the statistics for the numeric data in the 2019 dataset.
statistics_numeric_data
# Out:
#               Column Name Data Type  Unique Values  Repeated Values  Missing Values  count         mean       std     min          25%          50%          75%          max     Mode  Variance  Skewness  Kurtosis
# 0  economy_GDP_per_capita   float64            742               40               0  782.0     0.916047  0.407340     0.0     0.606500     0.982205     1.236187     2.096000     0.00      0.17     -0.32     -0.69
# 1                  family   float64            732               50               0  782.0     1.078392  0.329548     0.0     0.869363     1.124735     1.327250     1.644000     0.00      0.11     -0.68      0.16
# 2                 freedom   float64            697               85               0  782.0     0.411091  0.152880     0.0     0.309768     0.431000     0.531000     0.724000     0.00      0.02     -0.52     -0.31
# ...

# %%
# Seleccionamos las columnas numéricas del dataframe
df_numericas = df_concat.columns[4:]  # Si ya tienes las columnas numéricas

# Creamos un gráfico de distribuciones para cada columna numérica
plt.figure(figsize=(15, 10))  # Tamaño de la figura

# Iteramos sobre las columnas numéricas y creamos un gráfico de distribución para cada una
for i, col in enumerate(df_numericas):
    plt.subplot(3, 3, i+1)  # Creamos un subplot (ajustando las filas y columnas)
    sns.histplot(df_concat[col], kde=True, bins=30, color="skyblue")  # Usamos histplot con KDE para mostrar la distribución
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

# Mostrar la visualización
plt.show()

# %% [markdown]
# column 'year'

# %%
#ver el rango de años
df_concat['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019])

# %%
# Group the data by 'year' and count the unique countries for each year
unique_countries_per_year = df_concat.groupby("year")["country"].nunique()

# Set up the plot with a specified figure size
plt.figure(figsize=(10, 6))

# Plot the number of unique countries per year as a line plot
plt.plot(unique_countries_per_year.index, unique_countries_per_year.values, marker='o', color='b', linestyle='-')

# Add title and labels in English for clarity
plt.title("Number of Unique Countries per Year")
plt.xlabel("Year")
plt.ylabel("Number of Unique Countries")

# Set the x-axis to show only the years present in the data
plt.xticks(unique_countries_per_year.index)

# Set the y-axis to show only integer values within the range of unique countries
# 'np.arange' generates a sequence of integers within the range of Y values
plt.yticks(np.arange(unique_countries_per_year.min(), unique_countries_per_year.max() + 1, 1))

# Display a grid for easier visualization of data points
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# happiness_rank

# %%
df_concat['happiness_rank'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: happiness_rank, dtype: int64

# %%
# Filter rows where 'happiness_rank' is duplicated within each 'year'
duplicates = df_concat[df_concat.duplicated(subset=['year', 'happiness_rank'], keep=False)]

# Sort the results by 'year' and 'happiness_rank' for better clarity in identifying duplicates
duplicates_sorted = duplicates.sort_values(by=['year', 'happiness_rank'])

# Display the sorted duplicates
print(f"There are {duplicates_sorted.shape[1]} countries that occupy the same rank in the same year")
duplicates_sorted
# Out:
# There are 11 countries that occupy the same rank in the same year
#      happiness_rank       country                           region  happiness_score  economy_GDP_per_capita   family  health_life_expectancy  freedom  government_corruption  generosity  year
# 81               82        Jordan  Middle East and Northern Africa            5.192                 0.90198  1.05392                 0.69639  0.40661                0.14293     0.11053  2015
# 82               82    Montenegro       Central and Eastern Europe            5.192                 0.97438  0.90557                 0.72521  0.18260                0.14296     0.16140  2015
# 191              34  Saudi Arabia  Middle East and Northern Africa            6.379                 1.48953  0.84829                 0.59267  0.37904                0.30008     0.15457  2016
# ...

# %% [markdown]
# country

# %%
# Filter countries in each rank (1, 2, 3)
top_1 = df_concat[df_concat['happiness_rank'] == 1]
top_2 = df_concat[df_concat['happiness_rank'] == 2]
top_3 = df_concat[df_concat['happiness_rank'] == 3]

# Count how many times each country appears in each rank
pais_top_1 = top_1['country'].value_counts()
pais_top_2 = top_2['country'].value_counts()
pais_top_3 = top_3['country'].value_counts()

# Display the results for each rank
print("Top 1 Countries and Counts:")
print(pais_top_1)

print("\nTop 2 Countries and Counts:")
print(pais_top_2)

print("\nTop 3 Countries and Counts:")
print(pais_top_3)

print("\nThe order of the countries appearing most often in the top 3 in all years is as follows:")
print(f"Top 1:{pais_top_1.index[0]}")
print(f"Top 2:{pais_top_2.index[0]}")
print(f"Top 3:{pais_top_3.index[0]}")
# Out:
# Top 1 Countries and Counts:
# country
# Finland        2
# Switzerland    1
# Denmark        1
# Norway         1
# Name: count, dtype: int64
#
# Top 2 Countries and Counts:
# country
# Denmark        2
# Iceland        1
# Switzerland    1
# Norway         1
# Name: count, dtype: int64
#
# Top 3 Countries and Counts:
# country
# Denmark    2
# Iceland    2
# Norway     1
# Name: count, dtype: int64
#
# The order of the countries appearing most often in the top 3 in all years is as follows:
# Top 1:Finland
# Top 2:Denmark
# Top 3:Denmark

# %% [markdown]
# region

# %%
df_concat['region'].head()
# Out:
# 0    Western Europe
# 1    Western Europe
# 2    Western Europe
# 3    Western Europe
# 4     North America
# Name: region, dtype: object

# %%
#ver la cantidad de regiones y su numero de repeticiones
df_concat['region'].value_counts()
# Out:
# region
# Sub-Saharan Africa                 196
# Central and Eastern Europe         145
# Latin America and Caribbean        111
# Western Europe                     103
# Middle East and Northern Africa     98
# Southeastern Asia                   44
# Southern Asia                       35
# Eastern Asia                        30
# North America                       10
# Australia and New Zealand           10
# Name: count, dtype: int64

# %%
# Filtramos por las regiones en cada ranking (1, 2, 3)
top_1 = df_concat[df_concat['happiness_rank'] == 1]
top_2 = df_concat[df_concat['happiness_rank'] == 2]
top_3 = df_concat[df_concat['happiness_rank'] == 3]

# Contamos cuántas veces aparece cada región en cada ranking
region_top_1 = top_1['region'].value_counts()
region_top_2 = top_2['region'].value_counts()
region_top_3 = top_3['region'].value_counts()

# Mostramos los resultados por cada ranking
print("Top 1 Regions and Counts:")
print(region_top_1)

print("\nTop 2 Regions and Counts:")
print(region_top_2)

print("\nTop 3 Regions and Counts:")
print(region_top_3)

# Mostramos la región que más aparece en cada Top
print("\nThe order of the regions appearing most often in the top 3 in all years is as follows:")
print(f"Top 1 Region: {region_top_1.index[0]}")
print(f"Top 2 Region: {region_top_2.index[0]}")
print(f"Top 3 Region: {region_top_3.index[0]}")
# Out:
# Top 1 Regions and Counts:
# region
# Western Europe    5
# Name: count, dtype: int64
#
# Top 2 Regions and Counts:
# region
# Western Europe    5
# Name: count, dtype: int64
#
# Top 3 Regions and Counts:
# region
# Western Europe    5
# Name: count, dtype: int64
#
# The order of the regions appearing most often in the top 3 in all years is as follows:
# Top 1 Region: Western Europe
# Top 2 Region: Western Europe
# Top 3 Region: Western Europe

# %% [markdown]
# In this section, it can be observed that when analyzing by regions and countries, the top three countries in the overall ranking are from the Western Europe region. This could be due to various economic factors that benefit this region more than others, as well as other external factors that we are currently unable to measure with precision. Therefore, a correlation matrix will be created to examine which factors influence the happiness score and, consequently, the ranking. Afterwards, a machine learning model will be trained to help us better understand these fluctuations.

# %%
#exportar el dataframe
df_concat.to_csv('../data/processed/happiness_dataset.csv', index=False)
